# %%
import requests as r
from bs4 import BeautifulSoup as bs
import pandas as pd
import urllib
import numpy as np
import time
import json
from tqdm import tqdm
from math import ceil
import unicodedata

uri = 'https://www.clarin.com'

def dict_extract(key, var):
    ''' saca value de la key recurrentemente clarin'''
    if hasattr(var,'items'):
        for k, v in var.items():
            if k == key:
                yield v
            if isinstance(v, dict):
                for result in dict_extract(key, v):
                    yield unicodedata.normalize('NFKC',bs(result).text).strip()
            elif isinstance(v, list):
                for d in v:
                    for result in dict_extract(key, d):
                        yield unicodedata.normalize('NFKC',bs(result).text).strip()

class clarin():
    def __init__(self):
        self.url = 'https://www.clarin.com'


    def get(self, url):
        nota = r.get(url)
        self.url=url
        sopa = bs(nota.content, features="lxml")
        ps = sopa.find('div', 'body-nota').findAll('p')
        st = sopa.find('div', 'body-nota').findAll('strong')
        self.volanta = sopa.find('p', 'volanta').text
        self.titulo = sopa.find('h1').text
        try:
            self.bajada = sopa.find('div', 'bajada').find('h2').text
        except:
            pass
        texto = list()
        for p in ps:
            if p.text == "COMENTARIOS":
                break
            texto.append(p.text)
        bolds = list()
        for b in st:
            bolds.append(b.text)
        self.cuerpo = ' '.join(texto)
        self.bold = ' '.join(bolds)
        self.bolds = bolds
        self.date = sopa.find('span', {'class': 'publishedDate'}).get_text(strip=True)
        self.get_comments()  
        self.com = ' '.join(self.coms)
        
    def get_comments(self):
        url=self.url
        url0='https://login.clarin.com/comments.getStreamInfo'
        keys_0={'categoryID': ['Com_03'],
         'APIKey': ['2_fq_ZOJSR4xNZtv2rA8DALl1Gxp7yTYMb3UdER6zerupB55mwkzh9pVBz4Blzi8SW'],
         'sdk': ['js_latest'],
         'authMode': ['cookie'],
         'format': ['jsonp'],
         'callback': ['gigya.callback']}

        keys_0['streamID']=url[-14:-5]
        cm0=r.get(url0,params=keys_0)
        info = json.loads(cm0.text[15:-2])
        N=info['streamInfo']['threadCount']

        keys = {'categoryID': ['Com_03'],
         'includeSettings': ['true'],
         'threaded': ['true'],
         'includeStreamInfo': ['true'],
         'includeUserOptions': ['true'],
         'includeUserHighlighting': ['true'],
         'lang': ['es'],
         'ctag': ['comments_v2'],
         'APIKey': ['2_fq_ZOJSR4xNZtv2rA8DALl1Gxp7yTYMb3UdER6zerupB55mwkzh9pVBz4Blzi8SW'],
         'source': ['showCommentsUI'],
         'sdk': ['js_latest'],
         'authMode': ['cookie'],
         'format': ['jsonp'],
         'callback': ['gigya.callback']}

        keys['streamID']=url[-14:-5]
        coms=[]
        urlcm='https://login.clarin.com/comments.getComments'
        for x in range(ceil(N/10)):    
            req = json.loads(r.get(urlcm,params=keys).text[15:-2])

            #hay replies dentro de replies, busco recursivamente comentarios
            coms.extend(list(dict_extract('commentText', req)))

            #coms.extend([unicodedata.normalize('NFKC',bs(x['commentText']).text) for x in req['comments']])
            #for k in req['comments']:
            #    try: 
            #        coms.extend([unicodedata.normalize('NFKC',bs(rep['commentText']).text) for rep in k['replies']])
            #    except:
            #        pass

            req['comments'][-1]['timestamp']
            keys['start']='ts_'+str(req['comments'][-1]['timestamp'])
        self.coms=coms


months=['01','02','03','04','05','06','07','08','09','10','11','12']

def get_notas(year):
    for m in months:
        url = 'https://www.clarin.com/contents/sitemap_news_' + \
            year + '_' + m + '.xml'
        xml = r.get(url)
        sopa = bs(xml.content, features="lxml")
        urls = [x.get_text() for x in sopa.find_all('loc')]
        notas = []
        fails = []
        for i, x in enumerate(tqdm(urls)):
            nota = clarin()
            try:
                nota.get(x)
                notas.append(nota)
                time.sleep(0.1)
            except:
                fails.append(x)
        data = []
        for l, k in enumerate(notas):
            pupi = list()
            try:
                pupi.append(k.date)
                pupi.append(k.volanta)
                pupi.append(k.bajada)
                pupi.append(k.titulo)
                pupi.append(k.cuerpo)
                pupi.append(k.bold)
                pupi.append(k.com)
                pupi.append(urls[l])
                data.append(pupi)
            except:
                pass
        df = pd.DataFrame(data, columns=[
                          'date', 'volanta', 'bajada', 'titulo', 'cuerpo', 'bold', 'com', 'url'])
        df['cat'] = df.url.apply(lambda x: x.split('/')[3])
        df.to_csv(year + '_' + m +'.csv')
        print('fails: ', len(fails))


def notas(year,month):
    m = month
    url = 'https://www.clarin.com/contents/sitemap_news_' + \
        year + '_' + m + '.xml'
    xml = r.get(url)
    sopa = bs(xml.content, features="lxml")
    urls = [x.get_text() for x in sopa.find_all('loc')]
    notas = []
    fails = []
    for i, x in enumerate(tqdm(urls)):
        nota = clarin()
        try:
            nota.get(x)
            notas.append(nota)
            time.sleep(0.1)
        except:
            fails.append(x)
    data = []
    for l, k in enumerate(notas):
        pupi = list()
        try:
            pupi.append(k.date)
            pupi.append(k.volanta)
            pupi.append(k.bajada)
            pupi.append(k.titulo)
            pupi.append(k.cuerpo)
            pupi.append(k.bold)
            pupi.append(k.com)
            pupi.append(urls[l])
            data.append(pupi)
        except:
            pass
    df = pd.DataFrame(data, columns=[
                        'date', 'volanta', 'bajada', 'titulo', 'cuerpo', 'bold', 'com', 'url'])
    df['cat'] = df.url.apply(lambda x: x.split('/')[3])
    df.to_csv(year + '_' + m +'.csv')
    print('fails: ', len(fails))

# %%
year='2020'
m = '10'
url = 'https://www.clarin.com/contents/sitemap_news_' + \
    year + '_' + m + '.xml'
xml = r.get(url)
sopa = bs(xml.content, features="lxml")
urls = [x.get_text() for x in sopa.find_all('loc')]

# %%
nota=clarin()

# %%
urls.sort()

# %%
urls[9200:9500]
# Out:
# ['https://www.clarin.com/policiales/villa-gesell-hallan-mujer-muerta-detienen-pareja-denunciado-violencia-genero_0_sTjvN6zmj.html',
#  'https://www.clarin.com/politica/-girando-gobierno-sigue-igual-_0_q-Qg88MvQ.html',
#  'https://www.clarin.com/politica/-gobierno-nacional-provincial-usaron-hija-afirmo-madre-etchevehere-fallo_0_yasLx8l0g.html',
#  'https://www.clarin.com/politica/-manda-manda-encuestas-contradicen-carta-cristina-kirchner_0_3egucPMnL.html',
#  'https://www.clarin.com/politica/senado-oficialismo-avanza-debate-designar-procurador-oposicion-redefine-estrategia_0_X2gIj1Dlq.html',
#  'https://www.clarin.com/politica/sergio-berni-gente-juan-grabois-participacion-tomas-provincia-buenos-aires-_0_cgq7CKZMI.html',
#  'https://www.clarin.com/politica/sergio-berni-hablo-desalojo-guernica-grupos-izquierda-totalmente-armados-_0_2V3Vz32AW.html',
#  'https://www.clarin.com/politica/sergio-berni-reaparecio-spot-campana-grabo-desalojo-guernica_0_XgXpm4w_e.html',
#  'https://www.clarin.com/politica/sergio-massa-cede-baston-apuro-verde-aborto-vacuna-paso_0_BwxLCTmpn.html',
#  'https://www.clarin.com/politica/sip-lanza-campana-asesinato-periodistas-region_0_GxWGqyRko.html',
#  'https://www.clarin.com/politica/sobreseen-general-cesar-milani-causa-espionaje-ilegal-opositores-kirchnerismo_0_qLfwFlJ5X.html',
#  'https://www.clarin.com/politica/subsidio-bumeran-puede-alentar-tomas_0_8CXeXVS4G.html',
#  'https://www.clarin.com/politica/tensa-calma-guernica-policia-prepara-noche-alerta_0_dz3HVX8Np.html',
#  'https://www.clarin.com/politica/texto-completo-comunicado-academia-nacional-periodismo-rechazando-procesamiento-daniel-santoro_0_cmZ7RbW0D.html',
#  'https://www.clarin.com/politica/tomas-tierras-dijeron-funcionarios-gobierno-largo-conflicto_0_EzCxJlSUQ.html',
#  'https://www.clarin.com/politica/trastienda-decision-axel-kicillof-decidio-desalojo-compulsivo-guernica_0_vv2r1C_py.html',
#  'https://www.clarin.com/politica/ucr-acepta-negociar-candidatura-daniel-rafecas-espera-senal-alberto-fernandez_0_ao-1y0Bmk.html',
#  'https://www.clarin.com/politica/video-recuerdo-alberto-fernandez-nestor-kirchner-ultimo-jefe-politico-_0_dagVEoJlb.html',
#  'https://www.clarin.com/politica/vivo-alberto-fernandez-anuncia-nueva-extension-cuarentena-coronavirus_0_VLB7_h-h7.html',
#  'https://www.clarin.com/politica/vivo-senado-debate-proyecto-refinancia-deudas-provincias-anses_0_RmaaizYh1.html',
#  'https://www.clarin.com/politica/vivo-senado-rendira-homenaje-nestor-kirchner-tratar-multiples-proyectos-ley_0_NYyQlFnnC.html',
#  'https://www.clarin.com/provincias/acceder-creditos-comprar-arreglar-bicicletas-salta-capital_0_68P7ZT5dJ.html',
#  'https://www.clarin.com/provincias/alberto-fernandez-misiones-agradecimientos-demandas-gobernador-herrera-ahuad_0_JobKrJOJu.html',
#  'https://www.clarin.com/provincias/atacaron-estatua-nestor-kirchner-tartagal-quedo-destruida_0_L3BjRF2jp.html',
#  'https://www.clarin.com/provincias/avioneta-aterrizo-emergencia-ruta-12-misiones_0_2kIpigTEN.html',
#  'https://www.clarin.com/provincias/bancos-paraguayos-repletos-dolares-crisis-financiera-cierre-fronteras-misiones_0_2phw0KkyL.html',
#  'https://www.clarin.com/provincias/bebe-apunalada-posadas-dada-alta-entregada-papa_0_8tlCnHC2V.html',
#  'https://www.clarin.com/provincias/boom-tiktok-carceles-presos-salta-solo-podran-usar-celulares-camara_0_y6XVXQmvN.html',
#  'https://www.clarin.com/provincias/caso-abuso-sexual-golpea-iglesia-salta-detuvieron-cura_0_wKGd85Ezi.html',
#  'https://www.clarin.com/provincias/casos-coronavirus-hoy
#  'https://www.clarin.com/provincias/duda-polemica-estatua-nestor-kircher-parece-demasiado-senador-salteno-_0_LHEWdqdef.html',
#  'https://www.clarin.com/provincias/feroz-ataque-pitbull-abuela-vende-empanadas-oran-ahora-duenos-perros-peligrosos-deberan-registrarlos_0_zLUCVqppsE.html',
#  'https://www.clarin.com/provincias/fiestas-nubes-anticipan-misiones-kilo-lechon-llegara-800-pesos-_0_KAh09NTOi.html',
#  'https://www.clarin.com/provincias/furor-primavera-ocurrio-armar-bolsas-hielo-saborizado-terere-paran-vender_0_0mvIyWDuy.html',
#  'https://www.clarin.com/provincias/horror-pleno-centro-tucuman-mato-punaladas-profesora-suicido_0_NgTtP-8DN.html',
#  'https://www.clarin.com/provincias/horror-violaron-manada-hombre-filmaron-subieron-video-redes_0_V98qWVMHy.html',
#  'https://www.clarin.com/provincias/hospital-materno-infantil-salta-recibio-certificacion-mejor-equipados-latinoamerica_0_v56o_oadJ.html',
#  'https://www.clarin.com/provincias/ignacio-jarsun-diputado-salteno-justifico-linchamiento-caso-abigail-ahora-trataron-opa-_0_JG8cAJMvD.html',
#  'https://www.clarin.com/provincias/increible-detenciones-video-violacion-manada-hombre-familiares-dicen-broma-_0_WcFLXmEeL.html',
#  'https://www.clarin.com/provincias/investigan-posible-contrabando-soja-misiones-brasil-secuestraron-26-cargas-nombre-jubilados_0_A2LeZu_QP.html',
#  'https://www.clarin.com/provincias/llego-avion-misiones-coronavirus-denuncian-volo-ezeiza-certificado-vencido_0_cQZJrB-L1.html',
#  'https://www.clarin.com/provincias/misiones-fin-clases-pasara-aprueben_0_mpfwrYAij.html',
#  'https://www.clarin.com/provincias/misiones-hijo-ex-intendente-detenido-violacion-familiares-armaron-marcha-expusieron-victima_0_O1Tlb9c4T.html',
#  'https://www.clarin.com/provincias/misiones-muertos-triple-choque-ruta-14_0_vPaLhL2hf.html',
#  'https://www.clarin.com/provincias/primer-vuelo-salta-despues-meses-llega-75-asientos-ocupados-frecuencias-semana-inicial_0_hOBHq7SHa.html',
#  'https://www.clarin.com/provincias/primera-vez-minera-china-exportara-cloruro-litio-localidad-salta_0_EyCx5nLLz.html',
#  'https://www.clarin.com/provincias/provincia-provincia-requisitos-ingresar-regreso-vuelos-micros_0_dDFoWliV4.html',
#  'https://www.clarin.com/provincias/sacaran-estatua-nestor-kirchner-pusieron-permiso-vandalizada_0_5ot35THze.html',
#  'https://www.clarin.com/provincias/salta-condenan-camionero-propago-coronavirus-donar-plasma-dinero-insumos-hospital_0_fdrM1yS4J.html',
#  'https://www.clarin.com/provincias/salta-hombre-detenido-tentativa-homicidio-empujar-pareja-18-anos-segundo-piso_0_jwecd3RzR.html',
#  'https://www.clarin.com/provincias/salta-ira-juicio-capitan-ejercito-acusado-violar-hijos_0_zrhhmsNZQ.html']

# %%
nota.get(urls[9201])

# %%
print(urls[9201])
# Out:
# https://www.clarin.com/politica/-girando-gobierno-sigue-igual-_0_q-Qg88MvQ.html

# %%
nota.get_comments()

# %%
nota.com
# Out:
# ''
